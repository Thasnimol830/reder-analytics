# %%
import pandas as pd
pd.set_option("display.max_columns",None)

# %%
data = pd.read_csv(r"C:\Users\thasn\Downloads\Dataset.xlsx - Sheet1.csv")
data.columns
# Out:
# Index(['CustomerID', 'Name', 'Age', 'Gender', 'Location', 'Email', 'Phone',
#        'Address', 'Segment', 'PurchaseHistory', 'SubscriptionDetails',
#        'ServiceInteractions', 'PaymentHistory', 'WebsiteUsage',
#        'ClickstreamData', 'EngagementMetrics', 'Feedback',
#        'MarketingCommunication', 'NPS', 'ChurnLabel', 'Timestamp'],
#       dtype='object')

# %%
# Out:
#   Cell In[103], line 1
#     Name:
#          ^
# SyntaxError: invalid syntax

# %%
data
# Out:
#        CustomerID                   Name  Age  Gender      Location  \
# 0            1001           Mark Barrett   31    Male    Andrewfort
# 1            1002           Jeremy Welch   66  Female   Millerhaven
# 2            1003          Brandon Patel   36  Female    Lozanostad
# 3            1004            Tina Martin   62  Female  South Dustin
# 4            1005  Christopher Rodriguez   68  Female    West James
# ...           ...                    ...  ...     ...           ...
# 12478       13479          Catherine Lee   55  Female    New Lauren
# 12479       13480       Kimberly Johnson   29    Male    Randymouth
# 12480       13481           Lisa Rodgers   38    Male     East Erin
# 12481       13482          Kristin Carey   26  Female      New Leah
# 12482       13483         Melissa Carter   29    Male   West Amanda
#
#                                Email                 Phone  \
# 0              allison74@example.net            3192528777
# ...

# %%
PurchaseHistory
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 PurchaseHistory
#
# NameError: name 'PurchaseHistory' is not defined

# %%
cols_to_extract = ['PurchaseHistory', 'SubscriptionDetails',
       'ServiceInteractions', 'PaymentHistory', 'WebsiteUsage',
       'ClickstreamData', 'EngagementMetrics', 'Feedback',
       'MarketingCommunication']

# %%
data['PurchaseHistory'].iloc[0]
# Out:
# "[{'Product': 'Frozen Cocktail Mixes', 'Frequency': 8, 'Value': 884.43}, {'Product': 'Printer, Copier & Fax Machine Accessories', 'Frequency': 7, 'Value': 397.14}, {'Product': 'Hockey Stick Care', 'Frequency': 10, 'Value': 498.92}, {'Product': 'Guacamole', 'Frequency': 2, 'Value': 718.43}, {'Product': 'Mortisers', 'Frequency': 2, 'Value': 614.08}, {'Product': 'Rulers', 'Frequency': 6, 'Value': 221.68}, {'Product': 'Invitations', 'Frequency': 3, 'Value': 660.04}]"

# %%
#subset
data['SubscriptionDetails'].iloc[0]
# Out:
# "{'Plan': 'Express', 'Start_Date': '2020-06-08', 'End_Date': '2022-10-27'}"

# %%
import ast
ast.literal_eval(data['PurchaseHistory'].iloc[0])
ast.literal_eval(data['SubscriptionDetails'].iloc[0])
# Out:
# {'Plan': 'Express', 'Start_Date': '2020-06-08', 'End_Date': '2022-10-27'}

# %%
def convert_string(col):
    if isinstance(col, str):
       return ast.literal_eval(col)
    return col
for col in cols_to_extract:
    data[col].apply(convert_string)

# %%
import ast
ast.literal_eval(data['PurchaseHistory'].iloc[0])
# Out:
# [{'Product': 'Frozen Cocktail Mixes', 'Frequency': 8, 'Value': 884.43},
#  {'Product': 'Printer, Copier & Fax Machine Accessories',
#   'Frequency': 7,
#   'Value': 397.14},
#  {'Product': 'Hockey Stick Care', 'Frequency': 10, 'Value': 498.92},
#  {'Product': 'Guacamole', 'Frequency': 2, 'Value': 718.43},
#  {'Product': 'Mortisers', 'Frequency': 2, 'Value': 614.08},
#  {'Product': 'Rulers', 'Frequency': 6, 'Value': 221.68},
#  {'Product': 'Invitations', 'Frequency': 3, 'Value': 660.04}]

# %%
data['PurchaseHistory'].apply(ast.literal_eval).explode()
# Out:
# 0        {'Product': 'Frozen Cocktail Mixes', 'Frequenc...
# 0        {'Product': 'Printer, Copier & Fax Machine Acc...
# 0        {'Product': 'Hockey Stick Care', 'Frequency': ...
# 0        {'Product': 'Guacamole', 'Frequency': 2, 'Valu...
# 0        {'Product': 'Mortisers', 'Frequency': 2, 'Valu...
#                                ...
# 12481    {'Product': 'Tractor Parts & Accessories', 'Fr...
# 12481    {'Product': 'Video Cards & Adapters', 'Frequen...
# 12481    {'Product': 'Clear Kerosene', 'Frequency': 3, ...
# 12481    {'Product': 'Tripod Spreaders', 'Frequency': 8...
# 12482    {'Product': 'Pool Brushes & Brooms', 'Frequenc...
# Name: PurchaseHistory, Length: 68628, dtype: object

# %%
def convert_string(col:str)->any:
     #THIS FUNCTION USED TO CONVERT STRING TO LIST/DICTIONARY USING AST.LITERAL_EVAL
     if isinstance(col,str):
          return ast.literal_eval(col)
     return col

extracted_tables={}

for col in cols_to_extract:
    data[col]= data[col].apply(convert_string)# convert string to list/dic

    if isinstance(data[col].iloc[0],list):
         temp = data[['CustomerID',col]].explode(col)
         normalized = pd.json_normalize(temp[col])
         normalized['CustomerID']= temp['CustomerID'].values
    elif isinstance(data[col].iloc[0],dict):
        normalized= pd.json_normalize(data[col])
        normalized['CustomerID']= data['CustomerID'].values
        extracted_tables[col]= normalized

# %%
SubscriptionDetails = extracted_tables['SubscriptionDetails']

# %%
extracted_tables.keys()
# Out:
# dict_keys(['SubscriptionDetails', 'WebsiteUsage', 'EngagementMetrics', 'Feedback'])

# %%
for k,v in extracted_tables.items():
    
    print(f'{k}:{v.shape}')
# Out:
# SubscriptionDetails:(12483, 4)
# WebsiteUsage:(12483, 3)
# EngagementMetrics:(12483, 3)
# Feedback:(12483, 3)

# %%
data.shape
# Out:
# (12483, 21)

# %%
## List
names = ['Emma','Victor','Liam','Olivia','Noah','Ava']
for name in names:
       print(name)
# Out:
# Emma
# Victor
# Liam
# Olivia
# Noah
# Ava

# %%
SubscriptionDetails, \
WebsiteUsage, \
EngagementMetrics
Feedback,
MarketingCommunication = [extracted_tables[k] for k in extracted_tables.keys()]

# %%
###Explanatory data analysis

# %%
#PurchaseHistory.describe(include=['number'])

# %%
##Feature ENGINEERING
